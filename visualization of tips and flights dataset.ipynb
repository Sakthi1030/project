# %%
import seaborn as sns
tips = sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(data = tips,x = 'total_bill')
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %%
sns.scatterplot(x='total_bill',y ='tip',data = tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
import matplotlib.pyplot as plt
sns.scatterplot(x = 'total_bill',y = 'tip',hue ='sex',size ='size',sizes =(50,100),data = tips)
plt.xlabel('Total_bill')
plt.ylabel('Tips')
plt.title('relationship between total bills and tips')
# Out:
# Text(0.5, 1.0, 'relationship between total bills and tips')

# %%
fights = sns.load_dataset('flights')
fights = fights.pivot('month','year','passengers')
sns.heatmap(fights,cmap = 'Blues',annot=True,fmt = 'd')
plt.title('passenger per month')
plt.xlabel('Year')
plt.ylabel('Month')
# Out:
# C:\Users\sakth\AppData\Local\Temp\ipykernel_16080\1062241570.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   fights = fights.pivot('month','year','passengers')
# Text(50.722222222222214, 0.5, 'Month')
